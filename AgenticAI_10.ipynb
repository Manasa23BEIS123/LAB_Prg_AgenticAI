# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa23BEIS123/LAB_Prg_AgenticAI/blob/main/AgenticAI_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-community langchain-groq duckduckgo-search -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 37.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 84.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.1-8b-instant",
    temperature=0.3
)

print("Groq model connected successfully!")
# Out:
# Groq model connected successfully!

# %%
# !pip install -U ddgs -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 11.6 MB/s eta 0:00:00

# %%
from langchain_community.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults()

def search_agent(topic):
    return search.run(f"latest news about {topic}")

print("Search Agent created successfully!")
# Out:
# Search Agent created successfully!

# %%
raw = search_agent("artificial intelligence")

print(raw)
# Out:
# snippet: 2 hours ago - AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide., title: AI News | Latest News | Insights Powering AI-Driven Business Growth, link: https://www.artificialintelligence-news.com/, snippet: 6 days ago - The latest news and top stories on artificial intelligence, including ChatGPT, AI Chatbot and Bard. ... Large language models like ChatGPT use a complicated series of equations to understand and respond to your prompts. Here’s a look inside the system. ... For the new initiative, Vanderbilt University researchers will work to create “digital twins” of water system networks. ... The widely used tool is drawing backlash from some parents concerned about privacy and uncomfortable with AI taking over a task once done by teachers., title: Artificial intelligence news: Chat AI, ChatGPT, AI generator, AI Chatbot and Bard | NBC News, link: https://www.nbcnews.com/artificial-intellig
# ...

# %%
def summariser_agent(raw_results):
    return llm.invoke(
        "Summarise these news results into 3 short bullet points:\n"
        + raw_results
    ).content

print("Summariser Agent created successfully!")
# Out:
# Summariser Agent created successfully!

# %%
def report_agent(topic, summary):
    return llm.invoke(
        f'Create a short Markdown report titled "News: {topic}". '
        f'Use a heading and these points:\n{summary}'
    ).content

print("Report Agent created successfully!")
# Out:
# Report Agent created successfully!

# %%
topic = "artificial intelligence"

# Agent 1: Search
raw = search_agent(topic)

# Agent 2: Summarise
summary = summariser_agent(raw)

# Agent 3: Create Markdown report
report = report_agent(topic, summary)

# Save the final report
with open("news_report.md", "w", encoding="utf-8") as f:
    f.write(report)

print("=" * 60)
print("FINAL NEWS REPORT")
print("=" * 60)
print(report)

print("\nSaved as news_report.md")
# Out:
# ...
# FINAL NEWS REPORT
# ...
# # News: Artificial Intelligence
#
# ## Summary of Recent Developments
#
# Here are 3 short bullet points summarizing the news:
#
# * Researchers at Vanderbilt University are working on creating "digital twins" of water system networks using artificial intelligence, aiming to improve efficiency and management of these systems.
# * Large language models like ChatGPT use complex equations to understand and respond to user prompts, sparking concerns about AI taking over tasks once done by humans.
# * Goldman Sachs has hired Google's Evan Kotsovinos as a partner and engineering head, as the company continues to invest in artificial intelligence and expand its capabilities.
#
# Saved as news_report.md

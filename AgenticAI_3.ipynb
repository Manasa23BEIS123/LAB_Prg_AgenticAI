# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa23BEIS123/LAB_Prg_AgenticAI/blob/main/AgenticAI_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 2.8 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="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",
    model="llama-3.1-8b-instant",
    temperature=0.3
)

print("Groq model connected!")
# Out:
# Groq model connected!

# %%
task = """
Write a short and polite email to my professor asking for a deadline extension.
Keep the email respectful and professional.
"""

draft = llm.invoke(task).content

print("----- DRAFT EMAIL -----")
print(draft)
# Out:
# ----- DRAFT EMAIL -----
# Here's a sample email:
#
# Subject: Request for Deadline Extension for [Assignment/Project Name]
#
# Dear Professor [Professor's Name],
#
# I hope this email finds you well. I am writing to request a deadline extension for the [Assignment/Project Name] that is due on [Original Due Date]. Due to [briefly mention a valid reason, e.g., "unforeseen circumstances" or "additional research requirements"], I need some extra time to complete the assignment to the best of my abilities.
#
# I am confident that with a short extension, I will be able to submit high-quality work that meets your expectations. I am estimating that I will need an additional [Specific Number of Days] to complete the assignment.
#
# I would greatly appreciate it if you could consider my request. If there's any additional information you need from me or if you'd like to discuss this further, please let me know.
#
# Thank you for your understanding and support.
#
# Sincerely,
# [Your Name]

# %%
print("----- DRAFT EMAIL -----")
print(draft)

decision = input(
    "\nType APPROVED to send, or anything else to reject: "
)

if decision.strip().upper() == "APPROVED":
    print("✅ Email sent!")
else:
    print("❌ Not sent. The draft was rejected.")
# Out:
# ----- DRAFT EMAIL -----
# Here's a sample email:
#
# Subject: Request for Deadline Extension for [Assignment/Project Name]
#
# Dear Professor [Professor's Name],
#
# I hope this email finds you well. I am writing to request a deadline extension for the [Assignment/Project Name] that is due on [Original Due Date]. Due to [briefly mention a valid reason, e.g., "unforeseen circumstances" or "additional research requirements"], I need some extra time to complete the assignment to the best of my abilities.
#
# I am confident that with a short extension, I will be able to submit high-quality work that meets your expectations. I am estimating that I will need an additional [Specific Number of Days] to complete the assignment.
#
# I would greatly appreciate it if you could consider my request. If there's any additional information you need from me or if you'd like to discuss this further, please let me know.
#
# Thank you for your understanding and support.
#
# Sincerely,
# [Your Name]
#
# ...
